# %% [markdown]
# <a href="https://colab.research.google.com/github/Shivappa/AIML/blob/main/Pandas_in_Detail.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

import numpy as np

# %%
votes = np.array([120, 240, 150])
ratings = np.array([4.1, 4.5, 3.9])
restaurants = np.array(['R1', 'R2', 'R3'])

# %%
votes_series = pd.Series(votes, index=restaurants, name='votes')

# %%
votes_series
# Out:
# R1    120
# R2    240
# R3    150
# Name: votes, dtype: int64

# %%
rating_series = pd.Series(ratings, index=restaurants, name='Scoring')

# %%
rating_series
# Out:
# R1    4.1
# R2    4.5
# R3    3.9
# Name: Scoring, dtype: float64

# %%
#Quick way to combine them Concatenation, Better way is Joins (Will do later)

pd.concat([votes_series, rating_series], axis=1)
# Out:
#     votes  Scoring
# R1    120      4.1
# R2    240      4.5
# R3    150      3.9

# %%
data = {
    "Restaurant": ["R1", "R2", "R3"],
    "Votes": [120, 240, 150],
    "Rating": [4.1, 4.5, 3.9]
}

# %%
df= pd.DataFrame(data)

# %%
df
# Out:
#   Restaurant  Votes  Rating
# 0         R1    120     4.1
# 1         R2    240     4.5
# 2         R3    150     3.9

# %%
 df.set_index('Restaurant', inplace=True)

# %%
df
# Out:
#             Votes  Rating
# Restaurant
# R1            120     4.1
# R2            240     4.5
# R3            150     3.9

# %%
superstore = pd.read_excel('/content/Sample - Superstore.xls')

# %%
superstore
# Out:
#       Row ID        Order ID Order Date  Ship Date       Ship Mode  \
# 0          1  CA-2016-152156 2016-11-08 2016-11-11    Second Class
# 1          2  CA-2016-152156 2016-11-08 2016-11-11    Second Class
# 2          3  CA-2016-138688 2016-06-12 2016-06-16    Second Class
# 3          4  US-2015-108966 2015-10-11 2015-10-18  Standard Class
# 4          5  US-2015-108966 2015-10-11 2015-10-18  Standard Class
# ...      ...             ...        ...        ...             ...
# 9989    9990  CA-2014-110422 2014-01-21 2014-01-23    Second Class
# 9990    9991  CA-2017-121258 2017-02-26 2017-03-03  Standard Class
# 9991    9992  CA-2017-121258 2017-02-26 2017-03-03  Standard Class
# 9992    9993  CA-2017-121258 2017-02-26 2017-03-03  Standard Class
# 9993    9994  CA-2017-119914 2017-05-04 2017-05-09    Second Class
#
#      Customer ID     Customer Name    Segment        Country             City  \
# 0       CG-12520       Claire Gute   Consumer  United States        Henderson
# ...

# %%
# Downloading and unziping the dataset
# !wget https://d2beiqkhq929f0.cloudfront.net/public_assets/assets/000/100/375/original/zomato_dataset.zip
# !unzip zomato_dataset.zip
# !mv zomato_dataset.csv .
# Out:
# --2025-12-12 16:01:11--  https://d2beiqkhq929f0.cloudfront.net/public_assets/assets/000/100/375/original/zomato_dataset.zip
# Resolving d2beiqkhq929f0.cloudfront.net (d2beiqkhq929f0.cloudfront.net)... 3.169.201.165, 3.169.201.14, 3.169.201.156, ...
# Connecting to d2beiqkhq929f0.cloudfront.net (d2beiqkhq929f0.cloudfront.net)|3.169.201.165|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 72602133 (69M) [application/zip]
# Saving to: ‘zomato_dataset.zip’
#
# zomato_dataset.zip  100%[===================>]  69.24M  90.8MB/s    in 0.8s
#
# 2025-12-12 16:01:12 (90.8 MB/s) - ‘zomato_dataset.zip’ saved [72602133/72602133]
#
# Archive:  zomato_dataset.zip
#   inflating: zomato_dataset.csv
# mv: 'zomato_dataset.csv' and './zomato_dataset.csv' are the same file

# %%
df= pd.read_csv('zomato_dataset.csv')

# %%
df.head()
# Out:
#                                                  url  \
# 0  https://www.zomato.com/bangalore/jalsa-banasha...
# 1  https://www.zomato.com/bangalore/spice-elephan...
# 2  https://www.zomato.com/SanchurroBangalore?cont...
# 3  https://www.zomato.com/bangalore/addhuri-udupi...
# 4  https://www.zomato.com/bangalore/grand-village...
#
#                                              address                   name  \
# 0  942, 21st Main Road, 2nd Stage, Banashankari, ...                  Jalsa
# 1  2nd Floor, 80 Feet Road, Near Big Bazaar, 6th ...         Spice Elephant
# 2  1112, Next to KIMS Medical College, 17th Cross...        San Churro Cafe
# 3  1st Floor, Annakuteera, 3rd Stage, Banashankar...  Addhuri Udupi Bhojana
# 4  10, 3rd Floor, Lakshmi Associates, Gandhi Baza...          Grand Village
#
#   online_order book_table   rate  votes                             phone  \
# 0          Yes        Yes  4.1/5    775    080 42297555\r\n+91 9743772233
# ...

# %%
ratings = df["rate"]

# %%
ratings
# Out:
# 0         4.1/5
# 1         4.1/5
# 2         3.8/5
# 3         3.7/5
# 4         3.8/5
#           ...
# 23188    3.8 /5
# 23189    3.9 /5
# 23190    2.8 /5
# 23191    2.5 /5
# 23192    4.3 /5
# Name: rate, Length: 23193, dtype: object

# %%
#3-4 columns to work with


df_new= df[["rate", "votes" ]]

# %%
df_new
# Out:
#          rate  votes
# 0       4.1/5    775
# 1       4.1/5    787
# 2       3.8/5    918
# 3       3.7/5     88
# 4       3.8/5    166
# ...       ...    ...
# 23188  3.8 /5    128
# 23189  3.9 /5     77
# 23190  2.8 /5    161
# 23191  2.5 /5     81
# 23192  4.3 /5    236
#
# [23193 rows x 2 columns]

# %%
df_new.rename(columns={'rate': 'Rating','votes':'Votes' }, inplace=True)
# Out:
# /tmp/ipython-input-1701495368.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_new.rename(columns={'rate': 'Rating','votes':'Votes' }, inplace=True)

# %%
df_new
# Out:
#        Rating  Votes
# 0       4.1/5    775
# 1       4.1/5    787
# 2       3.8/5    918
# 3       3.7/5     88
# 4       3.8/5    166
# ...       ...    ...
# 23188  3.8 /5    128
# 23189  3.9 /5     77
# 23190  2.8 /5    161
# 23191  2.5 /5     81
# 23192  4.3 /5    236
#
# [23193 rows x 2 columns]

# %%
df.rename(columns={'rate': 'Rating','votes':'Votes' }, inplace=True)

# %%
df
# Out:
#                                                      url  \
# 0      https://www.zomato.com/bangalore/jalsa-banasha...
# 1      https://www.zomato.com/bangalore/spice-elephan...
# 2      https://www.zomato.com/SanchurroBangalore?cont...
# 3      https://www.zomato.com/bangalore/addhuri-udupi...
# 4      https://www.zomato.com/bangalore/grand-village...
# ...                                                  ...
# 23188  https://www.zomato.com/bangalore/izakaya-gastr...
# 23189  https://www.zomato.com/bangalore/m-bar-bengalu...
# 23190  https://www.zomato.com/bangalore/keys-cafe-key...
# 23191  https://www.zomato.com/bangalore/bhagini-2-whi...
# 23192  https://www.zomato.com/bangalore/chime-sherato...
#
#                                                  address  \
# 0      942, 21st Main Road, 2nd Stage, Banashankari, ...
# 1      2nd Floor, 80 Feet Road, Near Big Bazaar, 6th ...
# 2      1112, Next to KIMS Medical College, 17th Cross...
# ...

# %%
df_new
# Out:
#        Rating  Votes
# 0       4.1/5    775
# 1       4.1/5    787
# 2       3.8/5    918
# 3       3.7/5     88
# 4       3.8/5    166
# ...       ...    ...
# 23188  3.8 /5    128
# 23189  3.9 /5     77
# 23190  2.8 /5    161
# 23191  2.5 /5     81
# 23192  4.3 /5    236
#
# [23193 rows x 2 columns]

# %%
#What's the average ratings we get for the restaurants in our platform

#1. We will remove /5
#2. Convert into float
#3. tAKE THE MEAN OF THE COLUMN

# %%
df_new['Rating'].str[0:-2].astype(float)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipython-input-1410871499.py in <cell line: 0>()
# ----> 1 df_new['Rating'].str[0:-2].astype(float)
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/generic.py in astype(self, dtype, copy, errors)
#    6641         else:
#    6642             # else, only a single dtype is given
# -> 6643             new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    6644             res = self._constructor_from_mgr(new_data, axes=new_data.axes)
#    6645             return res.__finalize__(self, method="astype")
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/internals/managers.py in astype(self, dtype, copy, errors)
#     428             copy = False
#     429
# --> 430         return self.apply(
#     431             "astype",
#     432             dtype=dtype,
#
# ...

# %%
df_new['only_rating']= df_new['Rating'].str[0:-2].replace('N', np.nan).astype(float)
# Out:
# /tmp/ipython-input-1997157600.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_new['only_rating']= df_new['Rating'].str[0:-2].replace('N', np.nan).astype(float)

# %%
df_new
# Out:
#        Rating  Votes  only_rating
# 0       4.1/5    775          4.1
# 1       4.1/5    787          4.1
# 2       3.8/5    918          3.8
# 3       3.7/5     88          3.7
# 4       3.8/5    166          3.8
# ...       ...    ...          ...
# 23188  3.8 /5    128          3.8
# 23189  3.9 /5     77          3.9
# 23190  2.8 /5    161          2.8
# 23191  2.5 /5     81          2.5
# 23192  4.3 /5    236          4.3
#
# [23193 rows x 3 columns]

# %%
df_new.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23193 entries, 0 to 23192
# Data columns (total 3 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Rating       23193 non-null  object
#  1   Votes        23193 non-null  int64
#  2   only_rating  23046 non-null  float64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 543.7+ KB

# %%
print(df_new['only_rating'].mean())
# Out:
# 3.9043825392692875

# %%
#alternative
df_new["only_ratings_alter"]= df_new['Rating'].str[0:-2]
# Out:
# /tmp/ipython-input-1136960818.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_new["only_ratings_alter"]= df_new['Rating'].str[0:-2]

# %%
df_new["only_ratings_alter"] = pd.to_numeric(df_new["only_ratings_alter"], errors='coerce')
#coerce is a parameter that will force the operation and convert values it cannot handle into nulls
# Out:
# /tmp/ipython-input-2446631805.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_new["only_ratings_alter"] = pd.to_numeric(df_new["only_ratings_alter"], errors='coerce')

# %%
df_new["only_ratings_alter"].mean()
# Out:
# np.float64(3.9043825392692875)

# %%
#practice


df.head()
# Out:
#                                                  url  \
# 0  https://www.zomato.com/bangalore/jalsa-banasha...
# 1  https://www.zomato.com/bangalore/spice-elephan...
# 2  https://www.zomato.com/SanchurroBangalore?cont...
# 3  https://www.zomato.com/bangalore/addhuri-udupi...
# 4  https://www.zomato.com/bangalore/grand-village...
#
#                                              address                   name  \
# 0  942, 21st Main Road, 2nd Stage, Banashankari, ...                  Jalsa
# 1  2nd Floor, 80 Feet Road, Near Big Bazaar, 6th ...         Spice Elephant
# 2  1112, Next to KIMS Medical College, 17th Cross...        San Churro Cafe
# 3  1st Floor, Annakuteera, 3rd Stage, Banashankar...  Addhuri Udupi Bhojana
# 4  10, 3rd Floor, Lakshmi Associates, Gandhi Baza...          Grand Village
#
#   online_order book_table Rating  Votes                             phone  \
# 0          Yes        Yes  4.1/5    775    080 42297555\r\n+91 9743772233
# ...

# %%
df["approx_cost(for two people)"]

#1. rename it to cost_for_two
#2. Make a new column that gives cost for 1
# Out:
# 0         '800.0'
# 1         '800.0'
# 2         '800.0'
# 3         '300.0'
# 4         '600.0'
#            ...
# 23188    '1200.0'
# 23189    '2000.0'
# 23190    '1200.0'
# 23191     '800.0'
# 23192    '2500.0'
# Name: approx_cost(for two people), Length: 23193, dtype: object

# %%
df.rename(columns={'approx_cost(for two people)': 'cost_for_two'}, inplace=True)

# %%
df['cost_for_two'] = df['cost_for_two'].str.replace("'", "").astype(float)

# %%
df['cost_for_one']= df['cost_for_two']/2

# %%
df
# Out:
#                                                      url  \
# 0      https://www.zomato.com/bangalore/jalsa-banasha...
# 1      https://www.zomato.com/bangalore/spice-elephan...
# 2      https://www.zomato.com/SanchurroBangalore?cont...
# 3      https://www.zomato.com/bangalore/addhuri-udupi...
# 4      https://www.zomato.com/bangalore/grand-village...
# ...                                                  ...
# 23188  https://www.zomato.com/bangalore/izakaya-gastr...
# 23189  https://www.zomato.com/bangalore/m-bar-bengalu...
# 23190  https://www.zomato.com/bangalore/keys-cafe-key...
# 23191  https://www.zomato.com/bangalore/bhagini-2-whi...
# 23192  https://www.zomato.com/bangalore/chime-sherato...
#
#                                                  address  \
# 0      942, 21st Main Road, 2nd Stage, Banashankari, ...
# 1      2nd Floor, 80 Feet Road, Near Big Bazaar, 6th ...
# 2      1112, Next to KIMS Medical College, 17th Cross...
# ...

# %%
#######

df_new["only_ratings_alter"].isna().sum()
# Out:
# np.int64(147)

# %%
#how do I get the rows where nuls where there
df_new[df_new["only_ratings_alter"].isna()]
# Out:
#       Rating  Votes  only_rating  only_ratings_alter
# 453      NEW      0          NaN                 NaN
# 813      NEW      0          NaN                 NaN
# 814      NEW      0          NaN                 NaN
# 824      NEW      0          NaN                 NaN
# 832      NEW      0          NaN                 NaN
# ...      ...    ...          ...                 ...
# 22520    NEW      0          NaN                 NaN
# 22525    NEW      0          NaN                 NaN
# 22585    NEW      0          NaN                 NaN
# 22798    NEW      0          NaN                 NaN
# 23089    NEW      0          NaN                 NaN
#
# [147 rows x 4 columns]

# %%
#i want data without the null values --> remove these 147 rows


df_new[~(df_new["only_ratings_alter"].isna())]
# Out:
#        Rating  Votes  only_rating  only_ratings_alter
# 0       4.1/5    775          4.1                 4.1
# 1       4.1/5    787          4.1                 4.1
# 2       3.8/5    918          3.8                 3.8
# 3       3.7/5     88          3.7                 3.7
# 4       3.8/5    166          3.8                 3.8
# ...       ...    ...          ...                 ...
# 23188  3.8 /5    128          3.8                 3.8
# 23189  3.9 /5     77          3.9                 3.9
# 23190  2.8 /5    161          2.8                 2.8
# 23191  2.5 /5     81          2.5                 2.5
# 23192  4.3 /5    236          4.3                 4.3
#
# [23046 rows x 4 columns]

# %%
#identified Nulls but we want to treat them

# %%
df_new["only_ratings_nulls_1"]= df_new["only_ratings_alter"].fillna(1)
# Out:
# /tmp/ipython-input-933260826.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_new["only_ratings_nulls_1"]= df_new["only_ratings_alter"].fillna(1)

# %%
df_new["only_ratings_nulls_mean"]=df_new["only_ratings_alter"].fillna(df_new["only_ratings_alter"].mean())
# Out:
# /tmp/ipython-input-3478709079.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_new["only_ratings_nulls_mean"]=df_new["only_ratings_alter"].fillna(df_new["only_ratings_alter"].mean())

# %%
df_new["only_ratings_nulls_value"]=df_new["only_ratings_alter"].fillna('New_Restaurant')
# Out:
# /tmp/ipython-input-1942349466.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_new["only_ratings_nulls_value"]=df_new["only_ratings_alter"].fillna('New_Restaurant')

# %%
df_new
# Out:
#        Rating  Votes  only_rating  only_ratings_alter  only_ratings_nulls_1  \
# 0       4.1/5    775          4.1                 4.1                   4.1
# 1       4.1/5    787          4.1                 4.1                   4.1
# 2       3.8/5    918          3.8                 3.8                   3.8
# 3       3.7/5     88          3.7                 3.7                   3.7
# 4       3.8/5    166          3.8                 3.8                   3.8
# ...       ...    ...          ...                 ...                   ...
# 23188  3.8 /5    128          3.8                 3.8                   3.8
# 23189  3.9 /5     77          3.9                 3.9                   3.9
# 23190  2.8 /5    161          2.8                 2.8                   2.8
# 23191  2.5 /5     81          2.5                 2.5                   2.5
# 23192  4.3 /5    236          4.3                 4.3                   4.3
#
#        only_ratings_nulls_mean only_ratings_nulls_value
# ...

# %%
df_new[df_new["only_ratings_alter"].isna()]
# Out:
#       Rating  Votes  only_rating  only_ratings_alter  only_ratings_nulls_1  \
# 453      NEW      0          NaN                 NaN                   1.0
# 813      NEW      0          NaN                 NaN                   1.0
# 814      NEW      0          NaN                 NaN                   1.0
# 824      NEW      0          NaN                 NaN                   1.0
# 832      NEW      0          NaN                 NaN                   1.0
# ...      ...    ...          ...                 ...                   ...
# 22520    NEW      0          NaN                 NaN                   1.0
# 22525    NEW      0          NaN                 NaN                   1.0
# 22585    NEW      0          NaN                 NaN                   1.0
# 22798    NEW      0          NaN                 NaN                   1.0
# 23089    NEW      0          NaN                 NaN                   1.0
#
#        only_ratings_nulls_mean only_ratings_nulls_value
# ...

# %%
#catergorical column

# %%
df.head()
# Out:
#                                                  url  \
# 0  https://www.zomato.com/bangalore/jalsa-banasha...
# 1  https://www.zomato.com/bangalore/spice-elephan...
# 2  https://www.zomato.com/SanchurroBangalore?cont...
# 3  https://www.zomato.com/bangalore/addhuri-udupi...
# 4  https://www.zomato.com/bangalore/grand-village...
#
#                                              address                   name  \
# 0  942, 21st Main Road, 2nd Stage, Banashankari, ...                  Jalsa
# 1  2nd Floor, 80 Feet Road, Near Big Bazaar, 6th ...         Spice Elephant
# 2  1112, Next to KIMS Medical College, 17th Cross...        San Churro Cafe
# 3  1st Floor, Annakuteera, 3rd Stage, Banashankar...  Addhuri Udupi Bhojana
# 4  10, 3rd Floor, Lakshmi Associates, Gandhi Baza...          Grand Village
#
#   online_order book_table Rating  Votes                             phone  \
# 0          Yes        Yes  4.1/5    775    080 42297555\r\n+91 9743772233
# ...

# %%
#whenever we cant find mean which happens in Categorical column like location, we can use Mode

# %%
#drop

df_new.drop("Rating", axis=1, inplace=True)
# Out:
# /tmp/ipython-input-4280392741.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_new.drop("Rating", axis=1, inplace=True)

# %%
df_new
# Out:
#        Votes  only_rating  only_ratings_alter  only_ratings_nulls_1  \
# 0        775          4.1                 4.1                   4.1
# 1        787          4.1                 4.1                   4.1
# 2        918          3.8                 3.8                   3.8
# 3         88          3.7                 3.7                   3.7
# 4        166          3.8                 3.8                   3.8
# ...      ...          ...                 ...                   ...
# 23188    128          3.8                 3.8                   3.8
# 23189     77          3.9                 3.9                   3.9
# 23190    161          2.8                 2.8                   2.8
# 23191     81          2.5                 2.5                   2.5
# 23192    236          4.3                 4.3                   4.3
#
#        only_ratings_nulls_mean only_ratings_nulls_value
# 0                          4.1                      4.1
# ...

# %%
#missing values drop

#drop_na --> explore yourself

# %%
#Unique elements

df['location'].unique()
# Out:
# array(['Banashankari', 'Basavanagudi', 'Jayanagar', 'Kumaraswamy Layout',
#        'Rajarajeshwari Nagar', 'Mysore Road', 'Uttarahalli',
#        'South Bangalore', 'Vijay Nagar', 'Bannerghatta Road', 'JP Nagar',
#        'BTM', 'Wilson Garden', 'Koramangala 5th Block', 'Shanti Nagar',
#        'Richmond Road', 'City Market', 'Bellandur', 'Sarjapur Road',
#        'Marathahalli', 'HSR', 'Old Airport Road', 'Indiranagar',
#        'Koramangala 1st Block', 'East Bangalore', 'MG Road',
#        'Brigade Road', 'Lavelle Road', 'Church Street', 'Ulsoor',
#        'Residency Road', 'Shivajinagar', 'Infantry Road',
#        'St. Marks Road', 'Cunningham Road', 'Race Course Road', 'Domlur',
#        'Koramangala 8th Block', 'Frazer Town', 'Ejipura', 'Vasanth Nagar',
#        'Jeevan Bhima Nagar', 'Old Madras Road', 'Commercial Street',
#        'Koramangala 6th Block', 'Majestic', 'Langford Town',
#        'Koramangala 7th Block', 'Brookefield', 'Whitefield',
# ...

# %%
df['location'].nunique()
# Out:
# 88

# %%
#alternative -- but better way

df['location'].value_counts()
# Out:
# location
# Koramangala 5th Block    1783
# BTM                      1456
# Indiranagar              1350
# HSR                      1162
# Jayanagar                1037
#                          ...
# Kanakapura Road             2
# West Bangalore              2
# Yelahanka                   2
# Magadi Road                 2
# KR Puram                    1
# Name: count, Length: 88, dtype: int64

# %%
#Practice Advance questions

# %%
#Filter using loc

df.head()
# Out:
#                                                  url  \
# 0  https://www.zomato.com/bangalore/jalsa-banasha...
# 1  https://www.zomato.com/bangalore/spice-elephan...
# 2  https://www.zomato.com/SanchurroBangalore?cont...
# 3  https://www.zomato.com/bangalore/addhuri-udupi...
# 4  https://www.zomato.com/bangalore/grand-village...
#
#                                              address                   name  \
# 0  942, 21st Main Road, 2nd Stage, Banashankari, ...                  Jalsa
# 1  2nd Floor, 80 Feet Road, Near Big Bazaar, 6th ...         Spice Elephant
# 2  1112, Next to KIMS Medical College, 17th Cross...        San Churro Cafe
# 3  1st Floor, Annakuteera, 3rd Stage, Banashankar...  Addhuri Udupi Bhojana
# 4  10, 3rd Floor, Lakshmi Associates, Gandhi Baza...          Grand Village
#
#   online_order book_table Rating  Votes                             phone  \
# 0          Yes        Yes  4.1/5    775    080 42297555\r\n+91 9743772233
# ...

# %%
df_explicit= df.set_index("name")

# %%
df_explicit= df_explicit.head(100)

# %%
df_explicit
# Out:
#                                                                      url  \
# name
# Jalsa                  https://www.zomato.com/bangalore/jalsa-banasha...
# Spice Elephant         https://www.zomato.com/bangalore/spice-elephan...
# San Churro Cafe        https://www.zomato.com/SanchurroBangalore?cont...
# Addhuri Udupi Bhojana  https://www.zomato.com/bangalore/addhuri-udupi...
# Grand Village          https://www.zomato.com/bangalore/grand-village...
# ...                                                                  ...
# Mangalore Pearl        https://www.zomato.com/bangalore/mangalore-pea...
# Twiststick House       https://www.zomato.com/bangalore/twiststick-ho...
# Cool Corner            https://www.zomato.com/bangalore/cool-corner-b...
# Pizza Mane             https://www.zomato.com/bangalore/pizza-mane-1-...
# Dal Tadkaa             https://www.zomato.com/bangalore/dal-tadkaa-ba...
#
#                                                                  address  \
# name
# ...

# %%
df_explicit.loc['Mangalore Pearl']
# Out:
# url                https://www.zomato.com/bangalore/mangalore-pea...
# address            197/F, 8th B Main, 27th Cross, 3rd Block, Jaya...
# online_order                                                     Yes
# book_table                                                        No
# Rating                                                         3.8/5
# Votes                                                            242
# phone                               +91 8880888315\r\n+91 9019966667
# location                                                   Jayanagar
# rest_type                                              Casual Dining
# dish_liked         Neer Dosa, Sea Food, Ghee Rice, Marwai Sukka, ...
# cuisines                      Mangalorean, Seafood, Chinese, Biryani
# cost_for_two                                                   650.0
# reviews_list       [('Rated 4.0', 'RATED\n  Nice place.. of cours...
# menu_item                                                         []
# ...

# %%
#update the ratings of all the restaurants with votes > 200

# %%
df_new.loc[df_new["Votes"]>200, "new_ratings"] = 3
# Out:
# /tmp/ipython-input-2355980418.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_new.loc[df_new["Votes"]>200, "new_ratings"] = 3

# %%
df_new
# Out:
#        Votes  only_rating  only_ratings_alter  only_ratings_nulls_1  \
# 0        775          4.1                 4.1                   4.1
# 1        787          4.1                 4.1                   4.1
# 2        918          3.8                 3.8                   3.8
# 3         88          3.7                 3.7                   3.7
# 4        166          3.8                 3.8                   3.8
# ...      ...          ...                 ...                   ...
# 23188    128          3.8                 3.8                   3.8
# 23189     77          3.9                 3.9                   3.9
# 23190    161          2.8                 2.8                   2.8
# 23191     81          2.5                 2.5                   2.5
# 23192    236          4.3                 4.3                   4.3
#
#        only_ratings_nulls_mean only_ratings_nulls_value  new_ratings
# 0                          4.1                      4.1          3.0
# ...

# %%
df_new.loc[df_new["Votes"]>200, "new_ratings"] = 4

# %%
df_new
# Out:
#        Votes  only_rating  only_ratings_alter  only_ratings_nulls_1  \
# 0        775          4.1                 4.1                   4.1
# 1        787          4.1                 4.1                   4.1
# 2        918          3.8                 3.8                   3.8
# 3         88          3.7                 3.7                   3.7
# 4        166          3.8                 3.8                   3.8
# ...      ...          ...                 ...                   ...
# 23188    128          3.8                 3.8                   3.8
# 23189     77          3.9                 3.9                   3.9
# 23190    161          2.8                 2.8                   2.8
# 23191     81          2.5                 2.5                   2.5
# 23192    236          4.3                 4.3                   4.3
#
#        only_ratings_nulls_mean only_ratings_nulls_value  new_ratings
# 0                          4.1                      4.1          4.0
# ...

# %%
#duplicates

df_new.duplicated()
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 23188     True
# 23189     True
# 23190     True
# 23191     True
# 23192     True
# Length: 23193, dtype: bool

# %%
df_new[df_new.duplicated()]
# Out:
#        Votes  only_rating  only_ratings_alter  only_ratings_nulls_1  \
# 13       918          3.8                 3.8                   3.8
# 32      2556          4.6                 4.6                   4.6
# 89       402          4.1                 4.1                   4.1
# 93        62          3.0                 3.0                   3.0
# 105      504          4.2                 4.2                   4.2
# ...      ...          ...                 ...                   ...
# 23188    128          3.8                 3.8                   3.8
# 23189     77          3.9                 3.9                   3.9
# 23190    161          2.8                 2.8                   2.8
# 23191     81          2.5                 2.5                   2.5
# 23192    236          4.3                 4.3                   4.3
#
#        only_ratings_nulls_mean only_ratings_nulls_value  new_ratings
# 13                         3.8                      3.8          4.0
# ...

# %%
#drop the duplicates

#keep the first occurance and remove others

df_new.drop_duplicates (keep='first')

df_new.drop_duplicates (keep='last')

df_new.drop_duplicates (keep=False) #remove all duplicates

# %%
df_new['only_rating'].duplicated()
# Out:
# 0        False
# 1         True
# 2        False
# 3        False
# 4         True
#          ...
# 23188     True
# 23189     True
# 23190     True
# 23191     True
# 23192     True
# Name: only_rating, Length: 23193, dtype: bool

# %%
#Aggregations, sorting

#Replicate all the thigs we have done in AMazon sales data, Strip ---> HW

# %%
# !wget https://d2beiqkhq929f0.cloudfront.net/public_assets/assets/000/101/214/original/amazon_data4.zip
# Out:
# --2025-12-12 17:32:20--  https://d2beiqkhq929f0.cloudfront.net/public_assets/assets/000/101/214/original/amazon_data4.zip
# Resolving d2beiqkhq929f0.cloudfront.net (d2beiqkhq929f0.cloudfront.net)... 13.249.135.141, 13.249.135.67, 13.249.135.161, ...
# Connecting to d2beiqkhq929f0.cloudfront.net (d2beiqkhq929f0.cloudfront.net)|13.249.135.141|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1943535 (1.9M) [application/zip]
# Saving to: ‘amazon_data4.zip’
#
# amazon_data4.zip    100%[===================>]   1.85M  1.58MB/s    in 1.2s
#
# 2025-12-12 17:32:22 (1.58 MB/s) - ‘amazon_data4.zip’ saved [1943535/1943535]

# %%
# !unzip amazon_data4.zip
# Out:
# Archive:  amazon_data4.zip
#   inflating: products.csv
#   inflating: orders.csv

# %%
pd.read_csv('orders.csv')
# Out:
#       product_id                                            user_id  \
# 0     B07JW9H4J1  AG3D6O4STAQKAY2UVGEUV46KN35Q,AHMY5CWJMMK5BJRBB...
# 1     B098NS6PVG  AECPFYFQVRUWC3KGNLJIOREFP5LQ,AGYYVPDD7YG7FYNBX...
# 2     B096MSW6CT  AGU3BBQ2V2DDAMOAKGFAWDDQ6QHA,AESFLDV2PT363T2AQ...
# 3     B08HDJ86NZ  AEWAZDZZJLQUYVOVGBEUKSLXHQ5A,AG5HTSFRRE6NL3M5S...
# 4     B08CF3B7N1  AE3Q6KSUK5P75D5HFYHCRAOLODSA,AFUGIFH5ZAFXRDSZH...
# ...          ...                                                ...
# 1460  B08L7J3T31  AHITFY6AHALOFOHOZEOC6XBP4FEA,AFRABBODZJZQB6Z4U...
# 1461  B01M6453MB  AFG5FM3NEMOL6BNFRV2NK5FNJCHQ,AGEINTRN6Z563RMLH...
# 1462  B009P2LIL4  AGVPWCMAHYQWJOQKMUJN4DW3KM5Q,AF4Q3E66MY4SR7YQZ...
# 1463  B00J5DYCCA  AF2JQCLSCY3QJATWUNNHUSVUPNQQ,AFDMLUXC5LS5RXDJS...
# 1464  B01486F4G6  AFGW5PT3R6ZAVQR4Y5MWVAKBZAYA,AG7QNJ2SCS5VS5VYY...
#
#                                               user_name  \
# 0     Manav,Adarsh gupta,Sundeep,S.Sayeed Ahmed,jasp...
# ...
